# %%
#2
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [1,2,3,4,5]
plt.plot(x,y)
plt.title("X vs Y")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
#3
program =  ["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.bar(program,popularity)
plt.title("Program and Popularity")
plt.xlabel("Programmin Languages")
plt.ylabel("Popularity")
plt.show()
# Out:
# Text(0, 0.5, 'Popularity')

# %%
#4
program =  ["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.pie(popularity,labels = program)
plt.title("Program and Popularity")
plt.xlabel("Programmin Languages")
plt.ylabel("Popularity")
plt.show()

# %%
#5
x = [1,3,6,7,2]
y = [2,8,1,3,5]
plt.scatter(x,y,s=80,facecolors='none',edgecolors="g")
plt.show()

# %%
#6.1
import pandas as pd
state = ["Maharashtra","Rajasthan","Uttar Pradesh","Kerala","Panjab","Jharkhand","Haryana","Orisha"] 
dic = {"May_2020" : [28078,17067,12670,19765,18566,5700,3450,2300],
       "June_2020" : [39678,13456,19654,10879,12009,9100,8700,7800]}
df = pd.DataFrame(dic,index=state)
df.plot.bar()
# Out:
# <Axes: >

# %%
#6.2
state = ["Maharashtra","Rajasthan","Uttar Pradesh","Kerala","Panjab","Jharkhand","Haryana","Orisha"] 
explode = (0.2,0,0,0,0,0,0,0)
May_2020 = [28078,17067,12670,19765,18566,5700,3450,2300]
June_2020 = [39678,13456,19654,10879,12009,9100,8700,7800]
plt.pie(May_2020,labels = state,explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x24505dc53d0>,
# ...
#  [Text(0.8870561132727484, 0.9503322849958562, 'Maharashtra'),
#   Text(-0.5909738809449967, 0.9277660653638982, 'Rajasthan'),
#   Text(-1.0899377770762513, 0.1484440706194759, 'Uttar Pradesh'),
#   Text(-0.7571116083379864, -0.7979862232644545, 'Kerala'),
#   Text(0.3875739775732257, -1.0294592813259147, 'Panjab'),
#   Text(0.9641749092806339, -0.5294966896154136, 'Jharkhand'),
#   Text(1.0697544406078348, -0.256174621693521, 'Haryana'),
#   Text(1.0975205083932427, -0.07381553804070255, 'Orisha')])

# %%
#6.3
state = ["Maharashtra","Rajasthan","Uttar Pradesh","Kerala","Panjab","Jharkhand","Haryana","Orisha"] 
May_2020 = [28078,17067,12670,19765,18566,5700,3450,2300]
June_2020 = [39678,13456,19654,10879,12009,9100,8700,7800]
plt.plot(state,May_2020)
plt.plot(state,June_2020)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Maharashtra'),
#   Text(1, 0, 'Rajasthan'),
#   Text(2, 0, 'Uttar Pradesh'),
#   Text(3, 0, 'Kerala'),
#   Text(4, 0, 'Panjab'),
#   Text(5, 0, 'Jharkhand'),
#   Text(6, 0, 'Haryana'),
#   Text(7, 0, 'Orisha')])

# %%
#6.4
plt.figure(figsize=(9,3))
plt.subplot(1,3,1)
plt.plot(June_2020,state)
plt.subplot(1,3,2)
plt.pie(June_2020,labels=state)
plt.subplot(1,3,3)
plt.bar(state,June_2020)
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Maharashtra'),
#   Text(1, 0, 'Rajasthan'),
#   Text(2, 0, 'Uttar Pradesh'),
#   Text(3, 0, 'Kerala'),
#   Text(4, 0, 'Panjab'),
#   Text(5, 0, 'Jharkhand'),
#   Text(6, 0, 'Haryana'),
#   Text(7, 0, 'Orisha')])
